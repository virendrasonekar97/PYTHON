# %% [markdown]
# <a href="https://colab.research.google.com/github/virendrasonekar97/PYTHON/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Feature
# Engineering

# %% [markdown]
# 1. What is a parameter?
#
#
# Parameter model ka wo element hai jise training ke time update kiya ja sakta hai, jaise weights in a neural network.
#
#
#
# 2. What is correlation?
#
#
# Correlation do variables ke beech relationship hai, jisme value +1 to -1 ke beech hoti hai.
#
#
#
# 3. What does negative correlation mean?
#
#
# Negative correlation matlab ek variable badhta hai to dusra variable ghat ta hai, jaise price aur demand.
#
#
#
# 4. Define Machine Learning. What are the main components in Machine Learning?
#
#
# Machine Learning data se automatically pattern seekhkar prediction/recommendation deta hai. Main components: data, algorithm, model, loss function, optimizer.
#
#
#
# 5. How does loss value help in determining whether the model is good or not?
#
#
# Loss value ye batata hai ki model kitna accurate hai. Kam loss value matlab model achha perform kar raha hai.
#
#
#
# 6. What are continuous and categorical variables?
#
#
# Continuous variables aise variables hain jinki value rang me aa sakti hai (like height, weight). Categorical variables distinct groups me divided hote hain (like gender: male/female).
#
#
#
# 7. How do we handle categorical variables in Machine Learning? What are the common techniques?
#
#
# Categorical variables ko encode karne ke liye common techniques hain: One Hot Encoding, Label Encoding, Ordinal Encoding.
#
#
#
# 8. What do you mean by training and testing a dataset?
#
#
# Training dataset se model seekhta hai, testing dataset se model ki performance evaluate ki jati hai.
#
#
#
# 9. What is sklearn.preprocessing?
#
#
# scikit-learn ka preprocessing module data ko transform karne ke liye use hota hai, jaise scaling, encoding, imputation.
#
#
#
# 10. What is a Test set?
#
#
# Test set wo dataset hai jisko train kiye gaye model par evaluate karte hain, taaki model ki accuracy check ki ja sake.
#
#
#
# 11. How do we split data for model fitting (training and testing) in Python?
#
#
# Python me data ko train-test split karne ke liye sklearn.model_selection ka train_test_split function use hota hai.
#
#
#
# 12. How do you approach a Machine Learning problem?
#
#
# Data collection
#
# Data cleaning aur preprocessing
#
# EDA (Exploratory Data Analysis)
#
# Feature engineering
#
# Model selection
#
# Training and evaluation
#
#
#
# 13. Why do we have to perform EDA before fitting a model to the data?
#
#
# EDA data ke pattern, outlier, aur missing values find karne me help karta hai, jisse sahi model fit ho sake.
#
#
# 14. How can you find correlation between variables in Python?
#
#
# Python me correlation find karne ke liye pandas ka .corr() method use hota hai.
#
#
#
# 15. What is causation? Explain difference between correlation and causation with an example.
#
#
# Causation ek variable dusre ko directly effect karta hai. Correlation sirf relationship batata hai, effect nahi. Example: Ice cream sales aur temperature correlated hain, but temperature ice cream sales ko cause karta hai.
#
#
#
# 16. What is an Optimizer? What are different types of optimizers? Explain each with an example.
#
#
# Optimizer model ke parameters ko update karta hai loss kam karne ke liye. Types: SGD (Stochastic Gradient Descent), Adam, RMSprop.
#
#
#
# 17. What is sklearn.linear_model ?
#
#
# scikit-learn ka linear_model module linear regression, logistic regression jaise algorithms provide karta hai.
#
#
#
# 18. What does model.fit() do? What arguments must be given?
#
#
# model.fit() data aur labels par model ko train karta hai. Arguments: X (features), y (labels).
#
#
#
# 19. What does model.predict() do? What arguments must be given?
#
#
# model.predict() trained model se prediction karta hai. Argument: new data (X).
#
#
#
# 20. What is feature scaling? How does it help in Machine Learning?
#
#
# Feature scaling se sabhi features ek range me aa jate hain, jisse model training stable hoti hai.
#
#
#
# 21. How do we perform scaling in Python?
#
#
# Python me scaling ke liye sklearn.preprocessing ka StandardScaler ya MinMaxScaler use hota hai.
#
#
#
# 22. Explain data encoding?
#
#
# Data encoding categorical data ko numerical format me convert karna hai, jisse ML algorithms use kar saken.
